# %% [markdown]
# ## Project 2

# %% [markdown]
# ### Please execute the code below and observe the output you get. Also, please learn how to use each of these statements to get a similar task done

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv') # Read CSV file
df.head(2) # Display first 2 rows
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 =  pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv') # Read CSV file
df1.head(2) # Display first 2 rows
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %% [markdown]
# ### 1. Get the Metadata from the above files.

# %%
df.info() # prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info() # prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# ### 2. Get the row names from the above files.

# %%
np.array(df.index) # creates a array of index and display same with data type.
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df.index.values # return n dimensional array with index.
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
np.array(df1.index) # creates a array of index and display same with data type.
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
df1.index.values # return n dimensional array with index.
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# ### 3. Change the column name from any of the above file.

# %%
df.columns[0] # Display name of the column at 0th index.
# Out:
# 'Indicator'

# %%
df.rename(columns={'Indicator':'Indicator_id'}).head(2) # Rename column name from Indicator to Indicator_id. Display first 2 rows.
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 4. Change the column name from any of the above file and store the changes made permanently.

# %%
df.rename(columns={'Indicator':'Indicator_id'}, inplace=True) # Rename column name from Indicator to Indicator_id and changes are replaced directly to the data frame used.
df.head(2) # Display first 2 rows from the data frame.
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 5. Change the names of multiple columns.

# %%
df.columns.values # return n dimensional array with column names.
# Out:
# array(['Indicator_id', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value',
#        'Numeric', 'Low', 'High', 'Comments'], dtype=object)

# %%
df.rename(columns={'PUBLISH STATES':'Publication Status', 'WHO region':'WHO Region'}, inplace=True) # Rename specified columns and changes are replaced directly to the data frame used. 
df.head(2) # Display first 2 rows of the dataframe.
# Out:
#                        Indicator_id Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 6. Arrange values of a particular column in ascending order.

# %%
df.sort_values(by='Year').head(5) # Sort the values in 'Year' column and display's first 5 rows.
# Out:
#                            Indicator_id Publication Status  Year WHO Region  \
# 0      Life expectancy at birth (years)          Published  1990     Europe
# 1270   Life expectancy at birth (years)          Published  1990     Europe
# 3193   Life expectancy at birth (years)          Published  1990     Europe
# 3194   Life expectancy at birth (years)          Published  1990     Europe
# 3197  Life expectancy at age 60 (years)          Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# ...

# %% [markdown]
# ### 7. Arrange multiple column values in ascending order.

# %%
# sort the values from multiple columns in the order specified for each column. 
# Display first 5 rows from the sorted dataframe.
df.sort_values(by=['Indicator_id','Country','Year','WHO Region','Publication Status'], 
               ascending=[True,True,True,True,True]).head(5)
# Out:
#                                          Indicator_id Publication Status  \
# 2798  Healthy life expectancy (HALE) at birth (years)          Published
# 3363  Healthy life expectancy (HALE) at birth (years)          Published
# 4456  Healthy life expectancy (HALE) at birth (years)          Published
# 2245  Healthy life expectancy (HALE) at birth (years)          Published
# 3689  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year             WHO Region World Bank income group      Country  \
# 2798  2000  Eastern Mediterranean              Low-income  Afghanistan
# 3363  2000  Eastern Mediterranean              Low-income  Afghanistan
# 4456  2000  Eastern Mediterranean              Low-income  Afghanistan
# 2245  2012  Eastern Mediterranean              Low-income  Afghanistan
# 3689  2012  Eastern Mediterranean              Low-income  Afghanistan
#
#              Sex  Display Value  Numeric  Low  High  Comments
# ...

# %%
df[['Indicator_id','Country']].head(2) # Display values of only those columns which are mentioned and return only first 2 rows.
# Out:
#                        Indicator_id  Country
# 0  Life expectancy at birth (years)  Andorra
# 1  Life expectancy at birth (years)  Andorra

# %% [markdown]
# ### 8. Make country as the first column of the dataframe.

# %%
df.columns.values # Return array of column values.
# Out:
# array(['Indicator_id', 'Publication Status', 'Year', 'WHO Region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value',
#        'Numeric', 'Low', 'High', 'Comments'], dtype=object)

# %%
dfTemp = df.copy() # Creates a deep copy of dataframe.
list(dfTemp) # returns the list of columns of dataframe.
# Out:
# ['Indicator_id',
#  'Publication Status',
#  'Year',
#  'WHO Region',
#  'World Bank income group',
#  'Country',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
cols = list(dfTemp) # returns list of all columns of data frame.
c = cols.pop(cols.index('Country')) # Get the index of 'Country' column. Remove the column based on index specified. Returns the index on removed column.
cols.insert(0, c) # Insert the removed column at first (index 0).
cols # returns all the columns which are rearranged.
# Out:
# ['Country',
#  'Indicator_id',
#  'Publication Status',
#  'Year',
#  'WHO Region',
#  'World Bank income group',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
dfTemp[cols].head(2) # display first 2 rows of modified dataframe with country column at the begining (first).
# Out:
#    Country                      Indicator_id Publication Status  Year  \
# 0  Andorra  Life expectancy at birth (years)          Published  1990
# 1  Andorra  Life expectancy at birth (years)          Published  2000
#
#   WHO Region World Bank income group         Sex  Display Value  Numeric  Low  \
# 0     Europe             High-income  Both sexes             77     77.0  NaN
# 1     Europe             High-income  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# Get all the unique columns with country as first.
# create the list of unique columns.
# displays first 2 rows of the unique columns which are created with 'Country' column as first column.
df[pd.unique(['Country'] + df.columns.tolist()).tolist()].head(2)
# Out:
#    Country                      Indicator_id Publication Status  Year  \
# 0  Andorra  Life expectancy at birth (years)          Published  1990
# 1  Andorra  Life expectancy at birth (years)          Published  2000
#
#   WHO Region World Bank income group         Sex  Display Value  Numeric  Low  \
# 0     Europe             High-income  Both sexes             77     77.0  NaN
# 1     Europe             High-income  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 9. Get the column array using a variable

# %%
df['WHO Region'].values # Returns the array of values of 'WHO Region' column.
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
df.Country.values # Returns the array of values of 'Country' column.
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %% [markdown]
# ### 10. Get the subset rows 11, 24, 37

# %%
df.iloc[[11,24,37]] # display the rows based on the row index.
# Out:
#                          Indicator_id Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %% [markdown]
# ### 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
# Get all the rows based on indices.
# exclude the rows which we got from above.
# display fist 60 rows of data from data frame.
df[~df.index.isin([5,12,23,56])].head(60)
# Out:
#                          Indicator_id Publication Status  Year  \
# 0    Life expectancy at birth (years)          Published  1990
# 1    Life expectancy at birth (years)          Published  2000
# 2   Life expectancy at age 60 (years)          Published  2012
# 3   Life expectancy at age 60 (years)          Published  2000
# 4    Life expectancy at birth (years)          Published  2012
# 6   Life expectancy at age 60 (years)          Published  1990
# 7   Life expectancy at age 60 (years)          Published  2012
# 8    Life expectancy at birth (years)          Published  2012
# 9    Life expectancy at birth (years)          Published  2000
# 10   Life expectancy at birth (years)          Published  2012
# 11   Life expectancy at birth (years)          Published  2012
# 13   Life expectancy at birth (years)          Published  2012
# 14   Life expectancy at birth (years)          Published  2000
# 15   Life expectancy at birth (years)          Published  1990
# ...

# %% [markdown]
# ## Load datasets from CSV

# %%
# Read the csv file and create a data frame.
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv') 
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv') 
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.head(5) # display first 5 rows from users data frame.
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions.head(5) # displays first 5 rows of sessions data frame.
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
products.head(5) # displays first 5 rows of products data frame.
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactions.head(5) # displays first 5 rows of transactions data frame.
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# ### 12. Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

# %%
# Merge transactions and users table using left merge.
pd.merge(transactions, users, how='left')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
# Another way of merging 2 different data frames.
transactions.merge(users, how='left')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %% [markdown]
# ### 13. Which transactions have a UserID not in users?

# %%
# Merge transactions and users table using left merge.
pd.merge(transactions, users, how='left')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
# Get all the user id's from transactions matching with users based on User ID
# Get all the transactions excluding above user id's
transactions[~transactions.UserID.isin(users.UserID)]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %% [markdown]
# ### 14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

# %%
# join transactions and users data frames using inner join.
transactions.merge(users, how='inner')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# ### 15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

# %%
# join transactions and users data frames using outer join.
transactions.merge(users, how='outer')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %% [markdown]
# ### 16. Determine which sessions occurred on the same day each user registered

# %%
# Merge users and sessions data frames using inner join. 
# Left data frame on 'UserId and 'Registered' column and right data frame on 'UserID and 'SessionDate' column.
users.merge(sessions, how='inner', left_on=['UserID','Registered'], right_on=['UserID','SessionDate'])
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %% [markdown]
# ### 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
# There are no common keys on users and products data frame to merge.
# create a new data frame with column key and userid.
# add value 1 for each row in data frame for column key.
df1 = pd.DataFrame({'key':np.repeat(1, users.shape[0]), 'UserID': users.UserID})

# create new data frame with column key and productid.
# add value 1 for each row in data frame for column key.
df2 = pd.DataFrame({'key':np.repeat(1, products.shape[0]), 'ProductID': products.ProductID})

# merge 2 data frames on column 'key' which are created above to get the result of cross join.
df1.merge(df2, on='key')[['UserID','ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# ### 18. Determine how much quantity of each product was purchased by each user

# %%
# There are no common keys on users and products data frame to merge.
# create a new data frame with column key and userid.
# add value 1 for each row in data frame for column key.
df1 = pd.DataFrame({'key':np.repeat(1, users.shape[0]), 'UserID': users.UserID})

# create new data frame with column key and productid.
# add value 1 for each row in data frame for column key.
df2 = pd.DataFrame({'key':np.repeat(1, products.shape[0]), 'ProductID': products.ProductID})

# merge 2 data frames on column 'key' which are created above to get the result of cross join. Select only 2 columns.
s = df1.merge(df2, on='key')[['UserID','ProductID']]

# merge the new data frame with transactions using left join on UserId and ProductID columns.
# Group the resulted data frame with 'UserID' and 'ProductID' columns.
# for each group of user id and product id, get the sum of quantity for each group.
# Reset the index of newly created dataframe with few columns.
# fill zero value to all the cell which contains value as NaN/na/null.
pd.merge(s, transactions, how='left', on=['UserID','ProductID']).groupby(['UserID','ProductID']).apply(
    lambda e: pd.Series(dict(Quantity=e.Quantity.sum()))).reset_index().fillna(0)
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %% [markdown]
# ### 19. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)

# %%
# Self join transaction dataframe.
# Merge transactions dataframe with same data frame on userid.
transactions.merge(transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %% [markdown]
# ### 20. Join each user to his/her first occuring transaction in the transactions table

# %%
# Merge users data frame with transactions data frame on UserID using left join.
# Group by users and get the first transaction.
users.merge(transactions, on="UserID", how='left').groupby(["User"]).first()
# Out:
#           UserID  Gender  Registered   Cancelled  TransactionID  \
# User
# Benjamin       5    male  2010-11-25         NaN            NaN
# Brielle        4  female  2013-07-17         NaN            NaN
# Caroline       3  female  2012-10-23  2016-06-07            2.0
# Charles        1    male  2012-12-21         NaN            4.0
# Pedro          2    male  2010-08-01  2010-08-08            5.0
#
#          TransactionDate  ProductID  Quantity
# User
# Benjamin             NaN        NaN       NaN
# Brielle              NaN        NaN       NaN
# Caroline      2011-05-26        4.0       1.0
# Charles       2012-08-26        2.0       3.0
# Pedro         2013-06-06        4.0       1.0

# %%
# Another method
# Merge users data frame with transactions data frame on UserID using left join.
u = users.merge(transactions, on="UserID", how='left')

# drop all the duplicate rows keeping only first row.
u.drop_duplicates(['User'])
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 3       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 7       4   Brielle  female  2013-07-17         NaN            NaN
# 8       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 3      2011-05-26        4.0       1.0
# 7             NaN        NaN       NaN
# 8             NaN        NaN       NaN

# %% [markdown]
# ### 21. Test to see if we can drop columns

# %%
# Display data of users data frame.
users
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
# Drop the column 'Cancelled' from the users data frame and display the result.
users.drop(columns=['Cancelled'])
# Out:
#    UserID      User  Gender  Registered
# 0       1   Charles    male  2012-12-21
# 1       2     Pedro    male  2010-08-01
# 2       3  Caroline  female  2012-10-23
# 3       4   Brielle  female  2013-07-17
# 4       5  Benjamin    male  2010-11-25

# %% [markdown]
# ### 22. Print statistics of users

# %%
# Gets the descriptive statistics of Users dataframe with UserId column
users.describe()
# Out:
#          UserID
# count  5.000000
# mean   3.000000
# std    1.581139
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %% [markdown]
# ### 23. Get the list of only male users

# %%
# Add condition to select only male users
users[users.Gender == 'male']
# Out:
#    UserID      User Gender  Registered   Cancelled
# 0       1   Charles   male  2012-12-21         NaN
# 1       2     Pedro   male  2010-08-01  2010-08-08
# 4       5  Benjamin   male  2010-11-25         NaN

# %% [markdown]
# ### 24. Get the name of the female user who has purchased some product

# %%
# Merge user dataframe with transaction using inner join.
# Select only 3 columns which are required to display.
u = users.merge(transactions, how='inner')[['UserID','User','Gender']]

# Add filter condition to select only female users.
u = u[u.Gender == 'female']

# Drop duplicate rows if any.
u = u.drop_duplicates()

# print user name
u.User
# Out:
# 3    Caroline
# Name: User, dtype: object

# %% [markdown]
# ### 25. Get the name of the product which was maximum purchased.

# %%
# Group transactions datafrane by ProductID column.
t = transactions.groupby('ProductID')
# Create a series with sum of Quantity of each product. Apply this function to the above groupby object created.
t = t.apply(lambda e: pd.Series(dict(Quantity=e.Quantity.sum())))
# Merge above created dataframe with products table using left join on ProductID column.
t = t.merge(products, how='left', on='ProductID')
# Add filter to select maximum quantity of the product purchased.
t[t.Quantity == max(t.Quantity)]
# Out:
#    ProductID  Quantity Product  Price
# 2          4        10       D  10.02

# %% [markdown]
# ### 26. Remove missing values from transactions.

# %%
# Print transactions data frame.
transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
# Remove any row which has missing value from transactions data frame.
transactions.dropna(axis=0)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %% [markdown]
# ### 27. Get the name of the user who has attended maximum session.

# %%
# Group sessions dataframe by UserID and get the session count of each user. 
s = sessions.groupby('UserID').count()
# Merge above data frame with users on UserID column using left merge.
s = s.merge(users, on='UserID', how='left')
# Select the user details who attended maximum number of sessions.
s = s[s.SessionID == max(s.SessionID)]
# print the user name.
print(s.User)
# Out:
# 2    Brielle
# Name: User, dtype: object

# %% [markdown]
# ### 28. Name the user who spent least amount

# %%
# Merge the transaction data frame with products to get the price details.
a = transactions.merge(products, on='ProductID')
# Group above data frame by UserID.
a = a.groupby('UserID')
# Create a series with sum of Price of each user spent. Apply this function to the above groupby object created.
a = a.apply(lambda e: pd.Series(dict(Price = e.Price.sum())))
# Merge the above data frame with users data frame to get the user name.
a = a.merge(users, on='UserID')
# Add condition to select the user who spend less amount.
a = a[a.Price == min(a.Price)]
# print the user name.
print(a.User)
# Out:
# 0    Charles
# Name: User, dtype: object

# %% [markdown]
# ### 29. Get the list of users who have not purchased any product

# %%
# Get the list of all the users based on UserID is present in transactions dataframe.
# Get the list of all the users excluding above selected users.
users[~users.UserID.isin(transactions.UserID)]
# Out:
#    UserID      User  Gender  Registered Cancelled
# 3       4   Brielle  female  2013-07-17       NaN
# 4       5  Benjamin    male  2010-11-25       NaN

# %% [markdown]
# ### 30. Get the list of transactions done by users who are not in users data frame.

# %%
# Get the list of all the transactions based on UserID is present in users dataframe.
# Get the list of all the transactions excluding above selected transactions.
transactions[~transactions.UserID.isin(users.UserID)]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
